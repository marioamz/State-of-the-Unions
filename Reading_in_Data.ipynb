# %% [markdown]
# ## Global To Dos:
# * read paper
# * visualizations (see below)

# %% [markdown]
# Section 1: Load and Preprocess Data

# %%
import read_data as rd
import importlib
importlib.reload(rd)
import nltk
import collections
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# PATH = '/mnt/dm-3/alix/Documents/MLPP2019/State-of-the-Unions/sotu/' # Alix Path
# PATH = # Mario Path
# PATH = # Aleister Path
filetype = '*txt'

# %%
speeches = rd.reading_data(PATH, filetype)

# %%
s_keys = speeches.keys()
count = collections.defaultdict(dict)

# if you want by president and year, put "by pres year"
# if you want by president only, put "by pres"
rd.make_dict(speeches, s_keys, count, "by pres")

# %% [markdown]
# Section 2: Exploratory Analysis

# %%
# visualize trends of X words over time - Mario

# %% [markdown]
# ### visualize top 5 words by president - Aleister

# %%
def plot_top_words(data, list_of_presidents, top_words, vertical=True):
    
    '''    
    Creates a barplot for the top words for each president
    Inputs:
        data: dictionary with wordcounts by president
        list_of_presidents (list of strings): if ["all"], it creates a plot for all presidents in the
        data. Otherwise, it needs a list with the names of interest
        top_words (int): number of k-top words
        vertical: if True, it plots vertical bars; else, bars are horizontally aligned
    Returns:
            It does not return anything but shows the plot.
    '''    
    
    if list_of_presidents[0] == "all":
        for president in data.keys():
            d = presidents[president]
            top_list = sorted(d, key=d.get, reverse=True)[:top_words]
            top_five = {word:val for word,val in d.items() if word in top_list}
            dataframe= pd.DataFrame(top_five.items(), columns=['Words', 'Count'])
            if vertical:
                sns.barplot(x="Words", y="Count", data=dataframe, order = top_list).set_title(president)
                plt.show()
            else:
                sns.barplot(y="Words", x="Count", data=dataframe, order = top_list).set_title(president)
                plt.show()
    else:
        for president in list_of_presidents:
            d = presidents[president]
            top_list = sorted(d, key=d.get, reverse=True)[:5]
            top_five = {word:val for word,val in d.items() if word in top_list}
            dataframe= pd.DataFrame(top_five.items(), columns=['Words', 'Count'])
            if vertical:
                sns.barplot(x="Words", y="Count", data=dataframe, order = top_list).set_title(president)
                plt.show()
            else:
                sns.barplot(y="Words", x="Count", data=dataframe, order = top_list).set_title(president)
                plt.show()

# %%
speeches = rd.reading_data("/Users/aleistermontfort/Desktop/speeches",'*.txt')
#speeeches = clean_data.clean_words(speeches)
s_keys = speeches.keys()
count = collections.defaultdict(dict)

# if you want by president and year, put "by pres year"
# if you want by president only, put "by pres"
presidents = rd.make_dict(speeches, s_keys, count, "by pres")
# Out:
# by pres

# %%
plot_top_words(presidents,['all'], 10, False)

# %%
# top words across all presidents - Alix

# %%
# feature engineering

# %%
# hyperparameter tuning

# %%
# models
